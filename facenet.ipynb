# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/github_facenet'
# Out:
# /content/drive/My Drive/github_facenet

# %% [markdown]
# ## install facenet **lib**

# %%
# !pip install facenet

# %% [markdown]
# ## align train img

# %%
# !python src/align/align_dataset_mtcnn.py '/content/drive/My Drive/github_facenet/train_img'  '/content/drive/My Drive/github_facenet/model_pre_img'  --image_size 182 --margin 44

# %% [markdown]
# ## model training_casiaA_softmax

# %%
# !python src/train_softmax.py --logs_base_dir '/content/drive/My Drive/github_facenet/logs' --models_base_dir '/content/drive/My Drive/github_facenet/models' --data_dir '/content/drive/My Drive/github_facenet/model_pre_img' --image_size 160 --model_def models.inception_resnet_v1 --lfw_dir '/content/drive/My Drive/github_facenet/lfw_align_160' --optimizer ADAM --learning_rate -1  --max_nrof_epochs 150 --keep_probability 0.8 --random_crop --random_flip --use_fixed_image_standardization  --learning_rate_schedule_file '/content/drive/My Drive/github_facenet/data/learning_rate_schedule_classifier_casia.txt' --weight_decay 5e-4 --embedding_size 512 --lfw_distance_metric 1  --lfw_use_flipped_images --lfw_subtract_mean --validation_set_split_ratio 0.05 --validate_every_n_epochs 5 --prelogits_norm_loss_factor 5e-4

# %% [markdown]
# ## Model training_vggface2_softmax

# %%
# !python src/train_softmax.py --logs_base_dir '/content/drive/My Drive/github_facenet/logs' --models_base_dir '/content/drive/My Drive/github_facenet/models' --data_dir '/content/drive/My Drive/github_facenet/model_pre_img' --image_size 160 --model_def models.inception_resnet_v1 --lfw_dir '/content/drive/My Drive/github_facenet/lfw_align_160' --optimizer ADAM --learning_rate -1 --max_nrof_epochs 500 --batch_size 90  --keep_probability 0.4 --random_flip --use_fixed_image_standardization  --learning_rate_schedule_file '/content/drive/My Drive/github_facenet/data/learning_rate_schedule_classifier_vggface2.txt' --weight_decay 5e-4 --embedding_size 512 --lfw_distance_metric 1 --lfw_use_flipped_images --lfw_subtract_mean --validation_set_split_ratio 0.01 --validate_every_n_epochs 5

# %% [markdown]
# ## Model tripletloss_training

# %%
# !python src/train_tripletloss.py --logs_base_dir '/content/drive/My Drive/github_facenet/logs' --models_base_dir '/content/drive/My Drive/github_facenet/models' --data_dir '/content/drive/My Drive/github_facenet/model_pre_img' --image_size 160 --model_def models.inception_resnet_v1  --lfw_dir '/content/drive/My Drive/github_facenet/lfw_align_160' --optimizer RMSPROP --learning_rate 0.01  --weight_decay 1e-4 --max_nrof_epochs 500

# %% [markdown]
# ## Freeze Graph

# %%
# !python src/freeze_graph.py '/content/drive/My Drive/github_facenet/model/20190410-194010' '/content/drive/My Drive/github_facenet/model/20190410-194010.pb'

# %% [markdown]
# ## Evaluation on LFW

# %%
# !python src/validate_on_lfw.py  '/content/drive/My Drive/github_facenet/lfw_align_160' '/content/drive/My Drive/github_facenet/pretrained_model' --distance_metric 1  --use_flipped_images --subtract_mean --use_fixed_image_standardization

# %% [markdown]
# ## Classifier_Train
#
# ---

# %% [markdown]
# ## align_train_img

# %%
# !python src/align/align_dataset_mtcnn.py  '/content/drive/My Drive/github_facenet/train_img' '/content/drive/My Drive/github_facenet/class_pre_img160' --image_size 160  --margin 32  --random_order  --gpu_memory_fraction 0.25

# %% [markdown]
# ## Classifier_train SVM

# %%
# !python src/classifier.py TRAIN_SVM  '/content/drive/My Drive/github_facenet/class_pre_img160' '/content/drive/My Drive/github_facenet/pretrained_model' '/content/drive/My Drive/github_facenet/class/svm_classifier.pkl' --batch_size 1000

# %% [markdown]
# ## Classifier_train KNN

# %%
# !python src/classifier.py TRAIN_KNN  '/content/drive/My Drive/github_facenet/class_pre_img160' '/content/drive/My Drive/github_facenet/pretrained_model' '/content/drive/My Drive/github_facenet/class/knn_classifier.pkl' --batch_size 1000
