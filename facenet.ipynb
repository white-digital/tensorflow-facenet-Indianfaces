# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd '/content/drive/My Drive/github_facenet'
# Out:
# /content/drive/My Drive/github_facenet

# %% [markdown]
# ## install facenet **lib**

# %%
# !pip install facenet

# %% [markdown]
# ## align train img

# %%
# !python src/align/align_dataset_mtcnn.py '/content/drive/My Drive/github_facenet/train_img'  '/content/drive/My Drive/github_facenet/pre_img'  --image_size 182 --margin 44

# %% [markdown]
# ## model training_casiaA_softmax

# %%
# !python src/train_softmax.py --logs_base_dir '/content/drive/My Drive/github_facenet/logs' --models_base_dir '/content/drive/My Drive/github_facenet/models' --data_dir '/content/drive/My Drive/github_facenet/pre_img' --image_size 160 --model_def models.inception_resnet_v1 --lfw_dir '/content/drive/My Drive/model_finetune/pre_imgs' --optimizer ADAM --learning_rate -1  --max_nrof_epochs 150 --keep_probability 0.8 --random_crop --random_flip --use_fixed_image_standardization  --learning_rate_schedule_file '/content/drive/My Drive/github_facenet/data/learning_rate_schedule_classifier_casia.txt' --weight_decay 5e-4 --embedding_size 512 --lfw_distance_metric 1  --lfw_use_flipped_images --lfw_subtract_mean --validation_set_split_ratio 0.05 --validate_every_n_epochs 5 --prelogits_norm_loss_factor 5e-4

# %% [markdown]
# ## Model training_vggface2_softmax

# %%
# !python src/train_softmax.py --logs_base_dir '/content/drive/My Drive/github_facenet/logs' --models_base_dir '/content/drive/My Drive/github_facenet/models' --data_dir '/content/drive/My Drive/github_facenet/pre_img' --image_size 160 --model_def models.inception_resnet_v1 --lfw_dir '/content/drive/My Drive/model_finetune/pre_imgs' --optimizer ADAM --learning_rate -1 --max_nrof_epochs 500 --batch_size 90  --keep_probability 0.4 --random_flip --use_fixed_image_standardization  --learning_rate_schedule_file '/content/drive/My Drive/github_facenet/data/learning_rate_schedule_classifier_vggface2.txt' --weight_decay 5e-4 --embedding_size 512 --lfw_distance_metric 1 --lfw_use_flipped_images --lfw_subtract_mean --validation_set_split_ratio 0.01 --validate_every_n_epochs 5

# %% [markdown]
# ## Model tripletloss_training

# %%
# !python src/train_tripletloss.py --logs_base_dir '/content/drive/My Drive/github_facenet/logs' --models_base_dir '/content/drive/My Drive/github_facenet/models' --data_dir '/content/drive/My Drive/github_facenet/pre_img' --image_size 160 --model_def models.inception_resnet_v1  --lfw_dir '/content/drive/My Drive/model_finetune/pre_imgs' --optimizer RMSPROP --learning_rate 0.01  --weight_decay 1e-4 --max_nrof_epochs 500

# %% [markdown]
# ## Evaluation on LFW

# %%
# !python src/validate_on_lfw.py  '/content/drive/My Drive/github_facenet/pre_img' 'trainned_model_path' --distance_metric 1  --use_flipped_images --subtract_mean --use_fixed_image_standardization

# %% [markdown]
# ## Classifier_train SVM

# %%
python src/classifier.py TRAIN SVM  '/content/drive/My Drive/github_facenet/pre_img' 'pretrained_model directtory' '/content/drive/My Drive/github_facenet/class/svm_classifier.pkl' --batch_size 1000

# %% [markdown]
# ## Classifier_train KNN

# %%
python src/classifier.py TRAIN KNN  '/content/drive/My Drive/github_facenet/pre_img' 'pretrained_model directtory' '/content/drive/My Drive/github_facenet/class/knn_classifier.pkl' --batch_size 1000
